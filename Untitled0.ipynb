# %% [markdown]
# <a href="https://colab.research.google.com/github/monicleks/Test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###hola me llamo san pedro juan

# %%
# prompt: para una tabla generica, con dato inventado y pyhton

import pandas as pd
import numpy as np

# Create a dictionary with some invented data
data = {
    'Nombre': ['Juan', 'María', 'Pedro', 'Ana', 'Luis'],
    'Edad': [25, 30, 22, 28, 35],
    'Ciudad': ['Madrid', 'Barcelona', 'Sevilla', 'Valencia', 'Bilbao'],
    'Puntuacion': [85.5, 92.0, 78.9, 88.2, 95.1]
}

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
#   Nombre  Edad     Ciudad  Puntuacion
# 0   Juan    25     Madrid        85.5
# 1  María    30  Barcelona        92.0
# 2  Pedro    22    Sevilla        78.9
# 3    Ana    28   Valencia        88.2
# 4   Luis    35     Bilbao        95.1
